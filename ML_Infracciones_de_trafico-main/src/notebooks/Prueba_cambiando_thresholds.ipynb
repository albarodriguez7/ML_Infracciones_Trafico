# %%
import sys
sys.path.append('src/utils')
import pandas as pd 
import bootcampviztools as bt
import matplotlib.pyplot as plt
import numpy as np
import os

import seaborn as sns

from lightgbm import LGBMClassifier, LGBMRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, make_scorer, precision_score, ConfusionMatrixDisplay,mean_absolute_percentage_error
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier, XGBRegressor

from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from scipy.stats import randint, uniform

pd.options.mode.copy_on_write = True

# %%
df = pd.read_csv("src/data_sample/dataset_definitivo.zip")
df
# Out:
#         MES_DENUNCIA  ANIO_DENUNCIA  MES_FIRMEZA             TIPO_ORGANISMO  \
# 0                  1           2018            4              Ayuntamientos
# 1                  1           2018            9              Ayuntamientos
# 2                  1           2020            2              Ayuntamientos
# 3                  1           2020            5              Ayuntamientos
# 4                  1           2020           12              Ayuntamientos
# ...              ...            ...          ...                        ...
# 315229            12           2023           12  Servei Catalán de Tráfico
# 315230            12           2023           12  Servei Catalán de Tráfico
# 315231            12           2023           12  Servei Catalán de Tráfico
# 315232            12           2023           12  Servei Catalán de Tráfico
# 315233            12           2023           12  Servei Catalán de Tráfico
#
#         CUANTIA  PUNTOS SEXO NOVEL             EDAD TIPO_INFRACCION  \
# 0         200.0       3    V    NO  De 45 a 54 años        6.-Otros
# 1         200.0       3    M    NO  De 35 a 44 años  3.-Tlfn. móvil
# 2         200.0       3    V    NO  De 45 a 54 años  3.-Tlfn. móvil
# 3         200.0       4    V    NO  De 25 a 34 años        6.-Otros
# 4         200.0       3    V    NO  De 55 a 64 años  3.-Tlfn. móvil
# ...         ...     ...  ...   ...              ...             ...
# 315229    500.0       6    V    NO  De 55 a 64 años    2.-Velocidad
# 315230    500.0       6    V    NO  De 55 a 64 años        6.-Otros
# 315231    500.0       6    V    NO  De 65 a 74 años        6.-Otros
# 315232    500.0       6    V    SI    Hasta 24 años        6.-Otros
# 315233    600.0       6    V    NO  De 25 a 34 años    2.-Velocidad
#
#        PROVINCIA_TRAMITE  NUM_INFRACCIONES
# 0              Barcelona                 1
# 1                 Girona                 1
# 2              Barcelona                 1
# 3                 Girona                 1
# 4                 Girona                 1
# ...                  ...               ...
# 315229         Tarragona                 1
# 315230         Barcelona                 1
# 315231         Barcelona                 1
# 315232            Girona                 1
# 315233            Girona                 1
#
# [315234 rows x 12 columns]

# %%
df = df.drop(columns= ["MES_DENUNCIA", "ANIO_DENUNCIA", "MES_FIRMEZA", "TIPO_ORGANISMO", "TIPO_INFRACCION", "PROVINCIA_TRAMITE"])  # Quitamos features que no influyen en la gravedad y otros que están tan realcionados que nos sobreajustaría el modelo
df
# Out:
#         CUANTIA  PUNTOS SEXO NOVEL             EDAD  NUM_INFRACCIONES
# 0         200.0       3    V    NO  De 45 a 54 años                 1
# 1         200.0       3    M    NO  De 35 a 44 años                 1
# 2         200.0       3    V    NO  De 45 a 54 años                 1
# 3         200.0       4    V    NO  De 25 a 34 años                 1
# 4         200.0       3    V    NO  De 55 a 64 años                 1
# ...         ...     ...  ...   ...              ...               ...
# 315229    500.0       6    V    NO  De 55 a 64 años                 1
# 315230    500.0       6    V    NO  De 55 a 64 años                 1
# 315231    500.0       6    V    NO  De 65 a 74 años                 1
# 315232    500.0       6    V    SI    Hasta 24 años                 1
# 315233    600.0       6    V    NO  De 25 a 34 años                 1
#
# [315234 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315234 entries, 0 to 315233
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   CUANTIA           315234 non-null  float64
#  1   PUNTOS            315234 non-null  int64
#  2   SEXO              315234 non-null  object
#  3   NOVEL             315234 non-null  object
#  4   EDAD              315234 non-null  object
#  5   NUM_INFRACCIONES  315234 non-null  int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 14.4+ MB

# %%
df.describe()
# Out:
#              CUANTIA         PUNTOS  NUM_INFRACCIONES
# count  315234.000000  315234.000000     315234.000000
# mean      383.352246       4.020978          3.341622
# std       259.215915       1.447564          7.532732
# min         0.000000       2.000000          1.000000
# 25%       200.000000       3.000000          1.000000
# 50%       300.000000       4.000000          1.000000
# 75%       500.000000       6.000000          3.000000
# max      6000.000000       6.000000        304.000000

# %%
df.PUNTOS.value_counts()
# Out:
# PUNTOS
# 4    130169
# 6     87555
# 2     70987
# 3     26523
# Name: count, dtype: int64

# %%
df["GRAVEDAD"] = (df["PUNTOS"] >= 4).astype(int)

# Si gravedad es mayor o igual que 4 = 1 (grave). Si gravedad menor o igual a 3 = 0 (no grave)
# 0 = no grave
# 1 = grave

# %%
df
# Out:
#         CUANTIA  PUNTOS SEXO NOVEL             EDAD  NUM_INFRACCIONES  \
# 0         200.0       3    V    NO  De 45 a 54 años                 1
# 1         200.0       3    M    NO  De 35 a 44 años                 1
# 2         200.0       3    V    NO  De 45 a 54 años                 1
# 3         200.0       4    V    NO  De 25 a 34 años                 1
# 4         200.0       3    V    NO  De 55 a 64 años                 1
# ...         ...     ...  ...   ...              ...               ...
# 315229    500.0       6    V    NO  De 55 a 64 años                 1
# 315230    500.0       6    V    NO  De 55 a 64 años                 1
# 315231    500.0       6    V    NO  De 65 a 74 años                 1
# 315232    500.0       6    V    SI    Hasta 24 años                 1
# 315233    600.0       6    V    NO  De 25 a 34 años                 1
#
#         GRAVEDAD
# 0              0
# 1              0
# 2              0
# 3              1
# 4              0
# ...          ...
# 315229         1
# 315230         1
# 315231         1
# 315232         1
# 315233         1
#
# [315234 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 315234 entries, 0 to 315233
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   CUANTIA           315234 non-null  float64
#  1   PUNTOS            315234 non-null  int64
#  2   SEXO              315234 non-null  object
#  3   NOVEL             315234 non-null  object
#  4   EDAD              315234 non-null  object
#  5   NUM_INFRACCIONES  315234 non-null  int64
#  6   GRAVEDAD          315234 non-null  int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 16.8+ MB

# %%
target = "GRAVEDAD"

# %%
bt.pinta_distribucion_categoricas(df, [target], mostrar_valores = True, relativa = True)

# %%
train_set, test_set = train_test_split(df, test_size = 0.2, random_state = 42, stratify=df["GRAVEDAD"])

# %%
corr = train_set.corr(numeric_only= "True")
serie_corr = np.abs(corr[target]).sort_values(ascending = False)
serie_corr
# Out:
# GRAVEDAD            1.000000
# PUNTOS              0.808432
# CUANTIA             0.287039
# NUM_INFRACCIONES    0.100446
# Name: GRAVEDAD, dtype: float64

# %%
# Convertimos la columna de SEXO en binaria 

pd.get_dummies(train_set["SEXO"], columns="SEXO", drop_first=True, dtype=int)
# Out:
#         V
# 103124  0
# 16281   1
# 29600   0
# 116042  1
# 177848  1
# ...    ..
# 61344   1
# 291454  1
# 178534  0
# 118582  1
# 221009  1
#
# [252187 rows x 1 columns]

# %%
train_set["SEXO"] = (train_set["SEXO"] == "V").astype(int) # V -> clase 1, M -> clase 0
test_set["SEXO"] = (test_set["SEXO"] == "V").astype(int) # V -> clase 1, M -> clase 0

# %%
train_set["SEXO"].value_counts()
# Out:
# SEXO
# 1    174197
# 0     77990
# Name: count, dtype: int64

# %%
# Convertimos la columna de NOVEL en binaria 

pd.get_dummies(train_set["NOVEL"], columns="NOVEL", drop_first=True, dtype=int)
# Out:
#         SI
# 103124   0
# 16281    0
# 29600    0
# 116042   0
# 177848   0
# ...     ..
# 61344    0
# 291454   0
# 178534   0
# 118582   0
# 221009   0
#
# [252187 rows x 1 columns]

# %%
train_set["NOVEL"] = (train_set["NOVEL"] == "SI").astype(int) # SI -> clase 1, NO -> clase 0
test_set["NOVEL"] = (test_set["NOVEL"] == "SI").astype(int) # SI -> clase 1, NO -> clase 0

# %%
train_set["NOVEL"].value_counts()
# Out:
# NOVEL
# 0    239761
# 1     12426
# Name: count, dtype: int64

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 252187 entries, 103124 to 221009
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   CUANTIA           252187 non-null  float64
#  1   PUNTOS            252187 non-null  int64
#  2   SEXO              252187 non-null  int64
#  3   NOVEL             252187 non-null  int64
#  4   EDAD              252187 non-null  object
#  5   NUM_INFRACCIONES  252187 non-null  int64
#  6   GRAVEDAD          252187 non-null  int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 15.4+ MB

# %%
df["EDAD"].value_counts()
# Out:
# EDAD
# De 35 a 44 años    67131
# De 25 a 34 años    66768
# De 45 a 54 años    61598
# De 55 a 64 años    44287
#  Hasta 24 años     37512
# De 65 a 74 años    24938
# Más de 74 años     13000
# Name: count, dtype: int64

# %%
# Aplicamos OE para la columna EDAD para otorgar un numero a cada rango de edad (en orden)

oe = OrdinalEncoder(categories=[[" Hasta 24 años", "De 25 a 34 años", "De 35 a 44 años", "De 45 a 54 años", "De 55 a 64 años", "De 65 a 74 años", "Más de 74 años"]])

train_set["EDAD"] = oe.fit_transform(train_set[["EDAD"]])
test_set["EDAD"] = oe.transform(test_set[["EDAD"]])

# %%
train_set["EDAD"] = train_set["EDAD"].astype(int)
test_set["EDAD"] = test_set["EDAD"].astype(int)
train_set["EDAD"].value_counts()
# Out:
# EDAD
# 2    53730
# 1    53389
# 3    49285
# 4    35395
# 0    29981
# 5    20056
# 6    10351
# Name: count, dtype: int64

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 252187 entries, 103124 to 221009
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   CUANTIA           252187 non-null  float64
#  1   PUNTOS            252187 non-null  int64
#  2   SEXO              252187 non-null  int64
#  3   NOVEL             252187 non-null  int64
#  4   EDAD              252187 non-null  int64
#  5   NUM_INFRACCIONES  252187 non-null  int64
#  6   GRAVEDAD          252187 non-null  int64
# dtypes: float64(1), int64(6)
# memory usage: 15.4 MB

# %%
# Separo X e Y

X_train = train_set.drop(columns=["GRAVEDAD", "PUNTOS", "CUANTIA"])  # Quitamos las columnas que estan totalmente relacionadas con la gravedad para que no filtren información
y_train = train_set["GRAVEDAD"]

X_test = test_set.drop(columns=["GRAVEDAD", "PUNTOS", "CUANTIA"])
y_test = test_set["GRAVEDAD"]

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (252187, 4) (252187,)
# (63047, 4) (63047,)

# %%
# Instanciamos modelos para comparar como es el CV de los demás

from sklearn.pipeline import Pipeline

lr_clf = Pipeline([
    ('scaler', StandardScaler()),
    ('model', LogisticRegression(max_iter=1000, class_weight="balanced"))
])

rf_clf = Pipeline([
    ('model', RandomForestClassifier(n_estimators=300, max_depth=10, random_state=42, n_jobs=-1, class_weight="balanced"))
])

lgb_clf_base = Pipeline([
    ('model', LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=31, random_state=42, n_jobs=-1, verbose=-1, class_weight="balanced"))
])

modelos_clf = {
    "Regresion Logistica": lr_clf,
    "Random Forest": rf_clf,
    "LightGBM": lgb_clf_base
}

# %%
for tipo, modelo in modelos_clf.items():
    print(f"{tipo}: ", end=" ")
    print(np.mean(cross_val_score(modelo, X_train, y_train, cv=5, scoring="recall")))
# Out:
# Regresion Logistica:  0.600514417302124
# Random Forest:  0.6992863370471983
# LightGBM:  0.7009742686858834

# %% [markdown]
# ### MODELO CON LIGHTGBM

# %%
from sklearn.model_selection import StratifiedKFold

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
# Modelo sencillo sin ajustar todos los hiperparametros de LightGBM

from sklearn.metrics import recall_score, f1_score, classification_report

lgb_base = LGBMClassifier(
    class_weight="balanced",   
    random_state=42,
    n_jobs=-1,
    verbose=-1)

lgb_base.fit(X_train, y_train)
y_pred = lgb_base.predict(X_test)

print("Recall test:", recall_score(y_test, y_pred))
print("F1 test:", f1_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Recall test: 0.6947295900792284
# F1 test: 0.7236887745948208
#               precision    recall  f1-score   support
#
#            0       0.42      0.50      0.46     19502
#            1       0.76      0.69      0.72     43545
#
#     accuracy                           0.63     63047
#    macro avg       0.59      0.60      0.59     63047
# weighted avg       0.65      0.63      0.64     63047

# %%
# Modelo con mejores hiperparámetros

lgb_clf = Pipeline([
    ("lgb", LGBMClassifier(
        random_state=42,
        verbose=-1,
        n_jobs=-1,
        class_weight="balanced"
    ))
])

param_distributions = {
    "lgb__n_estimators": randint(200, 900),
    "lgb__learning_rate": uniform(0.01, 0.19),
    "lgb__num_leaves": randint(16, 128),
    "lgb__min_child_samples": randint(10, 150),
    "lgb__max_depth": randint(-1, 21),
    "lgb__subsample": uniform(0.7, 0.3),
    "lgb__reg_alpha": uniform(0.0, 0.3),
    "lgb__reg_lambda": uniform(0.0, 2.0)
}

lgb_random = RandomizedSearchCV(
    estimator=lgb_clf,
    param_distributions=param_distributions,
    n_iter=40,
    scoring="recall",
    cv=cv,
    n_jobs=1,
    verbose=2,
    random_state=42
)

lgb_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV] END lgb__learning_rate=0.08116262258099886, lgb__max_depth=13, lgb__min_child_samples=116, lgb__n_estimators=271, lgb__num_leaves=76, lgb__reg_alpha=0.1790550473839461, lgb__reg_lambda=0.8916655057071823, lgb__subsample=0.7299924747454009; total time=   1.1s
# [CV] END lgb__learning_rate=0.08116262258099886, lgb__max_depth=13, lgb__min_child_samples=116, lgb__n_estimators=271, lgb__num_leaves=76, lgb__reg_alpha=0.1790550473839461, lgb__reg_lambda=0.8916655057071823, lgb__subsample=0.7299924747454009; total time=   1.3s
# [CV] END lgb__learning_rate=0.08116262258099886, lgb__max_depth=13, lgb__min_child_samples=116, lgb__n_estimators=271, lgb__num_leaves=76, lgb__reg_alpha=0.1790550473839461, lgb__reg_lambda=0.8916655057071823, lgb__subsample=0.7299924747454009; total time=   1.1s
# [CV] END lgb__learning_rate=0.08116262258099886, lgb__max_depth=13, lgb__min_child_samples=116, lgb__n_estimators=271, lgb__num_leaves=76, lgb__reg_alpha=0.1790550473839461, lgb__reg_lambda=0.8916655057071823, lgb__subsample=0.7299924747454009; total time=   1.2s
# [CV] END lgb__learning_rate=0.08116262258099886, lgb__max_depth=13, lgb__min_child_samples=116, lgb__n_estimators=271, lgb__num_leaves=76, lgb__reg_alpha=0.1790550473839461, lgb__reg_lambda=0.8916655057071823, lgb__subsample=0.7299924747454009; total time=   1.1s
# [CV] END lgb__learning_rate=0.09725728947351475, lgb__max_depth=19, lgb__min_child_samples=109, lgb__n_estimators=863, lgb__num_leaves=18, lgb__reg_alpha=0.006175348288740734, lgb__reg_lambda=1.9398197043239886, lgb__subsample=0.9497327922401264; total time=   2.6s
# [CV] END lgb__learning_rate=0.09725728947351475, lgb__max_depth=19, lgb__min_child_samples=109, lgb__n_estimators=863, lgb__num_leaves=18, lgb__reg_alpha=0.006175348288740734, lgb__reg_lambda=1.9398197043239886, lgb__subsample=0.9497327922401264; total time=   2.2s
# [CV] END lgb__learning_rate=0.09725728947351475, lgb__max_depth=19, lgb__min_child_samples=109, lgb__n_estimators=863, lgb__num_leaves=18, lgb__reg_alpha=0.006175348288740734, lgb__reg_lambda=1.9398197043239886, lgb__subsample=0.9497327922401264; total time=   2.4s
# [CV] END lgb__learning_rate=0.09725728947351475, lgb__max_depth=19, lgb__min_child_samples=109, lgb__n_estimators=863, lgb__num_leaves=18, lgb__reg_alpha=0.006175348288740734, lgb__reg_lambda=1.9398197043239886, lgb__subsample=0.9497327922401264; total time=   2.7s
# [CV] END lgb__learning_rate=0.09725728947351475, lgb__max_depth=19, lgb__min_child_samples=109, lgb__n_estimators=863, lgb__num_leaves=18, lgb__reg_alpha=0.006175348288740734, lgb__reg_lambda=1.9398197043239886, lgb__subsample=0.9497327922401264; total time=   2.1s
# [CV] END lgb__learning_rate=0.05034443102887247, lgb__max_depth=19, lgb__min_child_samples=67, lgb__n_estimators=221, lgb__num_leaves=123, lgb__reg_alpha=0.006918727512424727, lgb__reg_lambda=1.0495493205167783, lgb__subsample=0.8199582915145766; total time=   1.3s
# [CV] END lgb__learning_rate=0.05034443102887247, lgb__max_depth=19, lgb__min_child_samples=67, lgb__n_estimators=221, lgb__num_leaves=123, lgb__reg_alpha=0.006918727512424727, lgb__reg_lambda=1.0495493205167783, lgb__subsample=0.8199582915145766; total time=   1.4s
# [CV] END lgb__learning_rate=0.05034443102887247, lgb__max_depth=19, lgb__min_child_samples=67, lgb__n_estimators=221, lgb__num_leaves=123, lgb__reg_alpha=0.006918727512424727, lgb__reg_lambda=1.0495493205167783, lgb__subsample=0.8199582915145766; total time=   1.3s
# [CV] END lgb__learning_rate=0.05034443102887247, lgb__max_depth=19, lgb__min_child_samples=67, lgb__n_estimators=221, lgb__num_leaves=123, lgb__reg_alpha=0.006918727512424727, lgb__reg_lambda=1.0495493205167783, lgb__subsample=0.8199582915145766; total time=   1.2s
# [CV] END lgb__learning_rate=0.05034443102887247, lgb__max_depth=19, lgb__min_child_samples=67, lgb__n_estimators=221, lgb__num_leaves=123, lgb__reg_alpha=0.006918727512424727, lgb__reg_lambda=1.0495493205167783, lgb__subsample=0.8199582915145766; total time=   1.3s
# [CV] END lgb__learning_rate=0.01886647601058693, lgb__max_depth=14, lgb__min_child_samples=24, lgb__n_estimators=389, lgb__num_leaves=77, lgb__reg_alpha=0.23555278841790406, lgb__reg_lambda=0.39934756431671947, lgb__subsample=0.8542703315240834; total time=   1.7s
# [CV] END lgb__learning_rate=0.01886647601058693, lgb__max_depth=14, lgb__min_child_samples=24, lgb__n_estimators=389, lgb__num_leaves=77, lgb__reg_alpha=0.23555278841790406, lgb__reg_lambda=0.39934756431671947, lgb__subsample=0.8542703315240834; total time=   1.6s
# [CV] END lgb__learning_rate=0.01886647601058693, lgb__max_depth=14, lgb__min_child_samples=24, lgb__n_estimators=389, lgb__num_leaves=77, lgb__reg_alpha=0.23555278841790406, lgb__reg_lambda=0.39934756431671947, lgb__subsample=0.8542703315240834; total time=   1.7s
# [CV] END lgb__learning_rate=0.01886647601058693, lgb__max_depth=14, lgb__min_child_samples=24, lgb__n_estimators=389, lgb__num_leaves=77, lgb__reg_alpha=0.23555278841790406, lgb__reg_lambda=0.39934756431671947, lgb__subsample=0.8542703315240834; total time=   1.8s
# [CV] END lgb__learning_rate=0.01886647601058693, lgb__max_depth=14, lgb__min_child_samples=24, lgb__n_estimators=389, lgb__num_leaves=77, lgb__reg_alpha=0.23555278841790406, lgb__reg_lambda=0.39934756431671947, lgb__subsample=0.8542703315240834; total time=   1.9s
# [CV] END lgb__learning_rate=0.12255876808378806, lgb__max_depth=1, lgb__min_child_samples=60, lgb__n_estimators=846, lgb__num_leaves=36, lgb__reg_alpha=0.1351497755908629, lgb__reg_lambda=0.026529922319733057, lgb__subsample=0.9826605267054558; total time=   1.7s
# [CV] END lgb__learning_rate=0.12255876808378806, lgb__max_depth=1, lgb__min_child_samples=60, lgb__n_estimators=846, lgb__num_leaves=36, lgb__reg_alpha=0.1351497755908629, lgb__reg_lambda=0.026529922319733057, lgb__subsample=0.9826605267054558; total time=   1.1s
# [CV] END lgb__learning_rate=0.12255876808378806, lgb__max_depth=1, lgb__min_child_samples=60, lgb__n_estimators=846, lgb__num_leaves=36, lgb__reg_alpha=0.1351497755908629, lgb__reg_lambda=0.026529922319733057, lgb__subsample=0.9826605267054558; total time=   1.3s
# [CV] END lgb__learning_rate=0.12255876808378806, lgb__max_depth=1, lgb__min_child_samples=60, lgb__n_estimators=846, lgb__num_leaves=36, lgb__reg_alpha=0.1351497755908629, lgb__reg_lambda=0.026529922319733057, lgb__subsample=0.9826605267054558; total time=   1.3s
# [CV] END lgb__learning_rate=0.12255876808378806, lgb__max_depth=1, lgb__min_child_samples=60, lgb__n_estimators=846, lgb__num_leaves=36, lgb__reg_alpha=0.1351497755908629, lgb__reg_lambda=0.026529922319733057, lgb__subsample=0.9826605267054558; total time=   1.2s
# [CV] END lgb__learning_rate=0.11702476139065246, lgb__max_depth=7, lgb__min_child_samples=99, lgb__n_estimators=764, lgb__num_leaves=17, lgb__reg_alpha=0.20526990795364705, lgb__reg_lambda=0.8803049874792026, lgb__subsample=0.7366114704534336; total time=   2.6s
# [CV] END lgb__learning_rate=0.11702476139065246, lgb__max_depth=7, lgb__min_child_samples=99, lgb__n_estimators=764, lgb__num_leaves=17, lgb__reg_alpha=0.20526990795364705, lgb__reg_lambda=0.8803049874792026, lgb__subsample=0.7366114704534336; total time=   2.0s
# [CV] END lgb__learning_rate=0.11702476139065246, lgb__max_depth=7, lgb__min_child_samples=99, lgb__n_estimators=764, lgb__num_leaves=17, lgb__reg_alpha=0.20526990795364705, lgb__reg_lambda=0.8803049874792026, lgb__subsample=0.7366114704534336; total time=   1.6s
# [CV] END lgb__learning_rate=0.11702476139065246, lgb__max_depth=7, lgb__min_child_samples=99, lgb__n_estimators=764, lgb__num_leaves=17, lgb__reg_alpha=0.20526990795364705, lgb__reg_lambda=0.8803049874792026, lgb__subsample=0.7366114704534336; total time=   1.6s
# [CV] END lgb__learning_rate=0.11702476139065246, lgb__max_depth=7, lgb__min_child_samples=99, lgb__n_estimators=764, lgb__num_leaves=17, lgb__reg_alpha=0.20526990795364705, lgb__reg_lambda=0.8803049874792026, lgb__subsample=0.7366114704534336; total time=   1.7s
# [CV] END lgb__learning_rate=0.10408361292114134, lgb__max_depth=13, lgb__min_child_samples=44, lgb__n_estimators=405, lgb__num_leaves=96, lgb__reg_alpha=0.07763399448000508, lgb__reg_lambda=1.325044568707964, lgb__subsample=0.7935133228268232; total time=   1.4s
# [CV] END lgb__learning_rate=0.10408361292114134, lgb__max_depth=13, lgb__min_child_samples=44, lgb__n_estimators=405, lgb__num_leaves=96, lgb__reg_alpha=0.07763399448000508, lgb__reg_lambda=1.325044568707964, lgb__subsample=0.7935133228268232; total time=   1.5s
# [CV] END lgb__learning_rate=0.10408361292114134, lgb__max_depth=13, lgb__min_child_samples=44, lgb__n_estimators=405, lgb__num_leaves=96, lgb__reg_alpha=0.07763399448000508, lgb__reg_lambda=1.325044568707964, lgb__subsample=0.7935133228268232; total time=   1.3s
# [CV] END lgb__learning_rate=0.10408361292114134, lgb__max_depth=13, lgb__min_child_samples=44, lgb__n_estimators=405, lgb__num_leaves=96, lgb__reg_alpha=0.07763399448000508, lgb__reg_lambda=1.325044568707964, lgb__subsample=0.7935133228268232; total time=   1.3s
# [CV] END lgb__learning_rate=0.10408361292114134, lgb__max_depth=13, lgb__min_child_samples=44, lgb__n_estimators=405, lgb__num_leaves=96, lgb__reg_alpha=0.07763399448000508, lgb__reg_lambda=1.325044568707964, lgb__subsample=0.7935133228268232; total time=   1.2s
# [CV] END lgb__learning_rate=0.10881292402378405, lgb__max_depth=8, lgb__min_child_samples=13, lgb__n_estimators=676, lgb__num_leaves=78, lgb__reg_alpha=0.25268543237849955, lgb__reg_lambda=0.8995082667395313, lgb__subsample=0.8185450708005443; total time=   1.8s
# [CV] END lgb__learning_rate=0.10881292402378405, lgb__max_depth=8, lgb__min_child_samples=13, lgb__n_estimators=676, lgb__num_leaves=78, lgb__reg_alpha=0.25268543237849955, lgb__reg_lambda=0.8995082667395313, lgb__subsample=0.8185450708005443; total time=   1.9s
# [CV] END lgb__learning_rate=0.10881292402378405, lgb__max_depth=8, lgb__min_child_samples=13, lgb__n_estimators=676, lgb__num_leaves=78, lgb__reg_alpha=0.25268543237849955, lgb__reg_lambda=0.8995082667395313, lgb__subsample=0.8185450708005443; total time=   2.0s
# [CV] END lgb__learning_rate=0.10881292402378405, lgb__max_depth=8, lgb__min_child_samples=13, lgb__n_estimators=676, lgb__num_leaves=78, lgb__reg_alpha=0.25268543237849955, lgb__reg_lambda=0.8995082667395313, lgb__subsample=0.8185450708005443; total time=   1.8s
# [CV] END lgb__learning_rate=0.10881292402378405, lgb__max_depth=8, lgb__min_child_samples=13, lgb__n_estimators=676, lgb__num_leaves=78, lgb__reg_alpha=0.25268543237849955, lgb__reg_lambda=0.8995082667395313, lgb__subsample=0.8185450708005443; total time=   1.8s
# [CV] END lgb__learning_rate=0.1860651845008209, lgb__max_depth=14, lgb__min_child_samples=24, lgb__n_estimators=655, lgb__num_leaves=93, lgb__reg_alpha=0.058794858725743554, lgb__reg_lambda=0.09045457782107613, lgb__subsample=0.7975990992289792; total time=   2.1s
# [CV] END lgb__learning_rate=0.1860651845008209, lgb__max_depth=14, lgb__min_child_samples=24, lgb__n_estimators=655, lgb__num_leaves=93, lgb__reg_alpha=0.058794858725743554, lgb__reg_lambda=0.09045457782107613, lgb__subsample=0.7975990992289792; total time=   3.3s
# [CV] END lgb__learning_rate=0.1860651845008209, lgb__max_depth=14, lgb__min_child_samples=24, lgb__n_estimators=655, lgb__num_leaves=93, lgb__reg_alpha=0.058794858725743554, lgb__reg_lambda=0.09045457782107613, lgb__subsample=0.7975990992289792; total time=   2.5s
# [CV] END lgb__learning_rate=0.1860651845008209, lgb__max_depth=14, lgb__min_child_samples=24, lgb__n_estimators=655, lgb__num_leaves=93, lgb__reg_alpha=0.058794858725743554, lgb__reg_lambda=0.09045457782107613, lgb__subsample=0.7975990992289792; total time=   2.0s
# [CV] END lgb__learning_rate=0.1860651845008209, lgb__max_depth=14, lgb__min_child_samples=24, lgb__n_estimators=655, lgb__num_leaves=93, lgb__reg_alpha=0.058794858725743554, lgb__reg_lambda=0.09045457782107613, lgb__subsample=0.7975990992289792; total time=   2.1s
# [CV] END lgb__learning_rate=0.08384868504100158, lgb__max_depth=16, lgb__min_child_samples=120, lgb__n_estimators=252, lgb__num_leaves=39, lgb__reg_alpha=0.10702599800807679, lgb__reg_lambda=0.5618690193747615, lgb__subsample=0.8628088249474745; total time=   0.9s
# [CV] END lgb__learning_rate=0.08384868504100158, lgb__max_depth=16, lgb__min_child_samples=120, lgb__n_estimators=252, lgb__num_leaves=39, lgb__reg_alpha=0.10702599800807679, lgb__reg_lambda=0.5618690193747615, lgb__subsample=0.8628088249474745; total time=   1.0s
# [CV] END lgb__learning_rate=0.08384868504100158, lgb__max_depth=16, lgb__min_child_samples=120, lgb__n_estimators=252, lgb__num_leaves=39, lgb__reg_alpha=0.10702599800807679, lgb__reg_lambda=0.5618690193747615, lgb__subsample=0.8628088249474745; total time=   0.8s
# [CV] END lgb__learning_rate=0.08384868504100158, lgb__max_depth=16, lgb__min_child_samples=120, lgb__n_estimators=252, lgb__num_leaves=39, lgb__reg_alpha=0.10702599800807679, lgb__reg_lambda=0.5618690193747615, lgb__subsample=0.8628088249474745; total time=   0.8s
# [CV] END lgb__learning_rate=0.08384868504100158, lgb__max_depth=16, lgb__min_child_samples=120, lgb__n_estimators=252, lgb__num_leaves=39, lgb__reg_alpha=0.10702599800807679, lgb__reg_lambda=0.5618690193747615, lgb__subsample=0.8628088249474745; total time=   0.8s
# [CV] END lgb__learning_rate=0.0367756027452049, lgb__max_depth=13, lgb__min_child_samples=54, lgb__n_estimators=264, lgb__num_leaves=104, lgb__reg_alpha=0.2960660809801552, lgb__reg_lambda=1.5444895385933148, lgb__subsample=0.7596147044602517; total time=   1.4s
# [CV] END lgb__learning_rate=0.0367756027452049, lgb__max_depth=13, lgb__min_child_samples=54, lgb__n_estimators=264, lgb__num_leaves=104, lgb__reg_alpha=0.2960660809801552, lgb__reg_lambda=1.5444895385933148, lgb__subsample=0.7596147044602517; total time=   1.5s
# [CV] END lgb__learning_rate=0.0367756027452049, lgb__max_depth=13, lgb__min_child_samples=54, lgb__n_estimators=264, lgb__num_leaves=104, lgb__reg_alpha=0.2960660809801552, lgb__reg_lambda=1.5444895385933148, lgb__subsample=0.7596147044602517; total time=   2.3s
# [CV] END lgb__learning_rate=0.0367756027452049, lgb__max_depth=13, lgb__min_child_samples=54, lgb__n_estimators=264, lgb__num_leaves=104, lgb__reg_alpha=0.2960660809801552, lgb__reg_lambda=1.5444895385933148, lgb__subsample=0.7596147044602517; total time=   3.1s
# [CV] END lgb__learning_rate=0.0367756027452049, lgb__max_depth=13, lgb__min_child_samples=54, lgb__n_estimators=264, lgb__num_leaves=104, lgb__reg_alpha=0.2960660809801552, lgb__reg_lambda=1.5444895385933148, lgb__subsample=0.7596147044602517; total time=   2.3s
# [CV] END lgb__learning_rate=0.011049202253484457, lgb__max_depth=9, lgb__min_child_samples=90, lgb__n_estimators=591, lgb__num_leaves=50, lgb__reg_alpha=0.2370526621593617, lgb__reg_lambda=1.2119199495620228, lgb__subsample=0.9778902635540047; total time=   4.3s
# [CV] END lgb__learning_rate=0.011049202253484457, lgb__max_depth=9, lgb__min_child_samples=90, lgb__n_estimators=591, lgb__num_leaves=50, lgb__reg_alpha=0.2370526621593617, lgb__reg_lambda=1.2119199495620228, lgb__subsample=0.9778902635540047; total time=   3.1s
# [CV] END lgb__learning_rate=0.011049202253484457, lgb__max_depth=9, lgb__min_child_samples=90, lgb__n_estimators=591, lgb__num_leaves=50, lgb__reg_alpha=0.2370526621593617, lgb__reg_lambda=1.2119199495620228, lgb__subsample=0.9778902635540047; total time=   2.8s
# [CV] END lgb__learning_rate=0.011049202253484457, lgb__max_depth=9, lgb__min_child_samples=90, lgb__n_estimators=591, lgb__num_leaves=50, lgb__reg_alpha=0.2370526621593617, lgb__reg_lambda=1.2119199495620228, lgb__subsample=0.9778902635540047; total time=   2.2s
# [CV] END lgb__learning_rate=0.011049202253484457, lgb__max_depth=9, lgb__min_child_samples=90, lgb__n_estimators=591, lgb__num_leaves=50, lgb__reg_alpha=0.2370526621593617, lgb__reg_lambda=1.2119199495620228, lgb__subsample=0.9778902635540047; total time=   2.1s
# [CV] END lgb__learning_rate=0.13370463484536946, lgb__max_depth=5, lgb__min_child_samples=81, lgb__n_estimators=232, lgb__num_leaves=63, lgb__reg_alpha=0.11124547565947991, lgb__reg_lambda=1.3376825053272146, lgb__subsample=0.8997767069852489; total time=   0.5s
# [CV] END lgb__learning_rate=0.13370463484536946, lgb__max_depth=5, lgb__min_child_samples=81, lgb__n_estimators=232, lgb__num_leaves=63, lgb__reg_alpha=0.11124547565947991, lgb__reg_lambda=1.3376825053272146, lgb__subsample=0.8997767069852489; total time=   0.5s
# [CV] END lgb__learning_rate=0.13370463484536946, lgb__max_depth=5, lgb__min_child_samples=81, lgb__n_estimators=232, lgb__num_leaves=63, lgb__reg_alpha=0.11124547565947991, lgb__reg_lambda=1.3376825053272146, lgb__subsample=0.8997767069852489; total time=   0.6s
# [CV] END lgb__learning_rate=0.13370463484536946, lgb__max_depth=5, lgb__min_child_samples=81, lgb__n_estimators=232, lgb__num_leaves=63, lgb__reg_alpha=0.11124547565947991, lgb__reg_lambda=1.3376825053272146, lgb__subsample=0.8997767069852489; total time=   0.5s
# [CV] END lgb__learning_rate=0.13370463484536946, lgb__max_depth=5, lgb__min_child_samples=81, lgb__n_estimators=232, lgb__num_leaves=63, lgb__reg_alpha=0.11124547565947991, lgb__reg_lambda=1.3376825053272146, lgb__subsample=0.8997767069852489; total time=   0.5s
# [CV] END lgb__learning_rate=0.12234657966446814, lgb__max_depth=20, lgb__min_child_samples=44, lgb__n_estimators=812, lgb__num_leaves=62, lgb__reg_alpha=0.21397343616689848, lgb__reg_lambda=1.5215700972337949, lgb__subsample=0.8683831592708489; total time=   3.1s
# [CV] END lgb__learning_rate=0.12234657966446814, lgb__max_depth=20, lgb__min_child_samples=44, lgb__n_estimators=812, lgb__num_leaves=62, lgb__reg_alpha=0.21397343616689848, lgb__reg_lambda=1.5215700972337949, lgb__subsample=0.8683831592708489; total time=   2.9s
# [CV] END lgb__learning_rate=0.12234657966446814, lgb__max_depth=20, lgb__min_child_samples=44, lgb__n_estimators=812, lgb__num_leaves=62, lgb__reg_alpha=0.21397343616689848, lgb__reg_lambda=1.5215700972337949, lgb__subsample=0.8683831592708489; total time=   3.3s
# [CV] END lgb__learning_rate=0.12234657966446814, lgb__max_depth=20, lgb__min_child_samples=44, lgb__n_estimators=812, lgb__num_leaves=62, lgb__reg_alpha=0.21397343616689848, lgb__reg_lambda=1.5215700972337949, lgb__subsample=0.8683831592708489; total time=   3.5s
# [CV] END lgb__learning_rate=0.12234657966446814, lgb__max_depth=20, lgb__min_child_samples=44, lgb__n_estimators=812, lgb__num_leaves=62, lgb__reg_alpha=0.21397343616689848, lgb__reg_lambda=1.5215700972337949, lgb__subsample=0.8683831592708489; total time=   3.0s
# [CV] END lgb__learning_rate=0.1564837641913666, lgb__max_depth=5, lgb__min_child_samples=36, lgb__n_estimators=592, lgb__num_leaves=94, lgb__reg_alpha=0.12826230550756487, lgb__reg_lambda=0.05083825348819038, lgb__subsample=0.7323674280979913; total time=   1.0s
# [CV] END lgb__learning_rate=0.1564837641913666, lgb__max_depth=5, lgb__min_child_samples=36, lgb__n_estimators=592, lgb__num_leaves=94, lgb__reg_alpha=0.12826230550756487, lgb__reg_lambda=0.05083825348819038, lgb__subsample=0.7323674280979913; total time=   1.6s
# [CV] END lgb__learning_rate=0.1564837641913666, lgb__max_depth=5, lgb__min_child_samples=36, lgb__n_estimators=592, lgb__num_leaves=94, lgb__reg_alpha=0.12826230550756487, lgb__reg_lambda=0.05083825348819038, lgb__subsample=0.7323674280979913; total time=   1.5s
# [CV] END lgb__learning_rate=0.1564837641913666, lgb__max_depth=5, lgb__min_child_samples=36, lgb__n_estimators=592, lgb__num_leaves=94, lgb__reg_alpha=0.12826230550756487, lgb__reg_lambda=0.05083825348819038, lgb__subsample=0.7323674280979913; total time=   1.2s
# [CV] END lgb__learning_rate=0.1564837641913666, lgb__max_depth=5, lgb__min_child_samples=36, lgb__n_estimators=592, lgb__num_leaves=94, lgb__reg_alpha=0.12826230550756487, lgb__reg_lambda=0.05083825348819038, lgb__subsample=0.7323674280979913; total time=   1.4s
# [CV] END lgb__learning_rate=0.015971545280479508, lgb__max_depth=5, lgb__min_child_samples=61, lgb__n_estimators=295, lgb__num_leaves=19, lgb__reg_alpha=0.2722699421778279, lgb__reg_lambda=0.4985844582977499, lgb__subsample=0.8231148769106889; total time=   0.7s
# [CV] END lgb__learning_rate=0.015971545280479508, lgb__max_depth=5, lgb__min_child_samples=61, lgb__n_estimators=295, lgb__num_leaves=19, lgb__reg_alpha=0.2722699421778279, lgb__reg_lambda=0.4985844582977499, lgb__subsample=0.8231148769106889; total time=   0.7s
# [CV] END lgb__learning_rate=0.015971545280479508, lgb__max_depth=5, lgb__min_child_samples=61, lgb__n_estimators=295, lgb__num_leaves=19, lgb__reg_alpha=0.2722699421778279, lgb__reg_lambda=0.4985844582977499, lgb__subsample=0.8231148769106889; total time=   0.8s
# [CV] END lgb__learning_rate=0.015971545280479508, lgb__max_depth=5, lgb__min_child_samples=61, lgb__n_estimators=295, lgb__num_leaves=19, lgb__reg_alpha=0.2722699421778279, lgb__reg_lambda=0.4985844582977499, lgb__subsample=0.8231148769106889; total time=   0.7s
# [CV] END lgb__learning_rate=0.015971545280479508, lgb__max_depth=5, lgb__min_child_samples=61, lgb__n_estimators=295, lgb__num_leaves=19, lgb__reg_alpha=0.2722699421778279, lgb__reg_lambda=0.4985844582977499, lgb__subsample=0.8231148769106889; total time=   0.8s
# [CV] END lgb__learning_rate=0.15355471632317927, lgb__max_depth=2, lgb__min_child_samples=22, lgb__n_estimators=359, lgb__num_leaves=86, lgb__reg_alpha=0.0869254358741304, lgb__reg_lambda=0.32244257450800884, lgb__subsample=0.9789092957027719; total time=   0.5s
# [CV] END lgb__learning_rate=0.15355471632317927, lgb__max_depth=2, lgb__min_child_samples=22, lgb__n_estimators=359, lgb__num_leaves=86, lgb__reg_alpha=0.0869254358741304, lgb__reg_lambda=0.32244257450800884, lgb__subsample=0.9789092957027719; total time=   0.5s
# [CV] END lgb__learning_rate=0.15355471632317927, lgb__max_depth=2, lgb__min_child_samples=22, lgb__n_estimators=359, lgb__num_leaves=86, lgb__reg_alpha=0.0869254358741304, lgb__reg_lambda=0.32244257450800884, lgb__subsample=0.9789092957027719; total time=   0.5s
# [CV] END lgb__learning_rate=0.15355471632317927, lgb__max_depth=2, lgb__min_child_samples=22, lgb__n_estimators=359, lgb__num_leaves=86, lgb__reg_alpha=0.0869254358741304, lgb__reg_lambda=0.32244257450800884, lgb__subsample=0.9789092957027719; total time=   0.5s
# [CV] END lgb__learning_rate=0.15355471632317927, lgb__max_depth=2, lgb__min_child_samples=22, lgb__n_estimators=359, lgb__num_leaves=86, lgb__reg_alpha=0.0869254358741304, lgb__reg_lambda=0.32244257450800884, lgb__subsample=0.9789092957027719; total time=   0.5s
# [CV] END lgb__learning_rate=0.16354287211723922, lgb__max_depth=19, lgb__min_child_samples=143, lgb__n_estimators=227, lgb__num_leaves=123, lgb__reg_alpha=0.05597101766581075, lgb__reg_lambda=1.7851179969799555, lgb__subsample=0.8618026725746952; total time=   1.0s
# [CV] END lgb__learning_rate=0.16354287211723922, lgb__max_depth=19, lgb__min_child_samples=143, lgb__n_estimators=227, lgb__num_leaves=123, lgb__reg_alpha=0.05597101766581075, lgb__reg_lambda=1.7851179969799555, lgb__subsample=0.8618026725746952; total time=   1.0s
# [CV] END lgb__learning_rate=0.16354287211723922, lgb__max_depth=19, lgb__min_child_samples=143, lgb__n_estimators=227, lgb__num_leaves=123, lgb__reg_alpha=0.05597101766581075, lgb__reg_lambda=1.7851179969799555, lgb__subsample=0.8618026725746952; total time=   1.0s
# [CV] END lgb__learning_rate=0.16354287211723922, lgb__max_depth=19, lgb__min_child_samples=143, lgb__n_estimators=227, lgb__num_leaves=123, lgb__reg_alpha=0.05597101766581075, lgb__reg_lambda=1.7851179969799555, lgb__subsample=0.8618026725746952; total time=   1.1s
# [CV] END lgb__learning_rate=0.16354287211723922, lgb__max_depth=19, lgb__min_child_samples=143, lgb__n_estimators=227, lgb__num_leaves=123, lgb__reg_alpha=0.05597101766581075, lgb__reg_lambda=1.7851179969799555, lgb__subsample=0.8618026725746952; total time=   1.1s
# [CV] END lgb__learning_rate=0.16341362948117188, lgb__max_depth=5, lgb__min_child_samples=138, lgb__n_estimators=576, lgb__num_leaves=42, lgb__reg_alpha=0.1281323365878769, lgb__reg_lambda=1.6360295318449862, lgb__subsample=0.9582191749769029; total time=   0.9s
# [CV] END lgb__learning_rate=0.16341362948117188, lgb__max_depth=5, lgb__min_child_samples=138, lgb__n_estimators=576, lgb__num_leaves=42, lgb__reg_alpha=0.1281323365878769, lgb__reg_lambda=1.6360295318449862, lgb__subsample=0.9582191749769029; total time=   1.2s
# [CV] END lgb__learning_rate=0.16341362948117188, lgb__max_depth=5, lgb__min_child_samples=138, lgb__n_estimators=576, lgb__num_leaves=42, lgb__reg_alpha=0.1281323365878769, lgb__reg_lambda=1.6360295318449862, lgb__subsample=0.9582191749769029; total time=   1.0s
# [CV] END lgb__learning_rate=0.16341362948117188, lgb__max_depth=5, lgb__min_child_samples=138, lgb__n_estimators=576, lgb__num_leaves=42, lgb__reg_alpha=0.1281323365878769, lgb__reg_lambda=1.6360295318449862, lgb__subsample=0.9582191749769029; total time=   1.0s
# [CV] END lgb__learning_rate=0.16341362948117188, lgb__max_depth=5, lgb__min_child_samples=138, lgb__n_estimators=576, lgb__num_leaves=42, lgb__reg_alpha=0.1281323365878769, lgb__reg_lambda=1.6360295318449862, lgb__subsample=0.9582191749769029; total time=   1.0s
# [CV] END lgb__learning_rate=0.011320904800926235, lgb__max_depth=6, lgb__min_child_samples=146, lgb__n_estimators=517, lgb__num_leaves=52, lgb__reg_alpha=0.2077308098670811, lgb__reg_lambda=0.538824667597043, lgb__subsample=0.7732376566743322; total time=   1.6s
# [CV] END lgb__learning_rate=0.011320904800926235, lgb__max_depth=6, lgb__min_child_samples=146, lgb__n_estimators=517, lgb__num_leaves=52, lgb__reg_alpha=0.2077308098670811, lgb__reg_lambda=0.538824667597043, lgb__subsample=0.7732376566743322; total time=   2.0s
# [CV] END lgb__learning_rate=0.011320904800926235, lgb__max_depth=6, lgb__min_child_samples=146, lgb__n_estimators=517, lgb__num_leaves=52, lgb__reg_alpha=0.2077308098670811, lgb__reg_lambda=0.538824667597043, lgb__subsample=0.7732376566743322; total time=   2.2s
# [CV] END lgb__learning_rate=0.011320904800926235, lgb__max_depth=6, lgb__min_child_samples=146, lgb__n_estimators=517, lgb__num_leaves=52, lgb__reg_alpha=0.2077308098670811, lgb__reg_lambda=0.538824667597043, lgb__subsample=0.7732376566743322; total time=   2.2s
# [CV] END lgb__learning_rate=0.011320904800926235, lgb__max_depth=6, lgb__min_child_samples=146, lgb__n_estimators=517, lgb__num_leaves=52, lgb__reg_alpha=0.2077308098670811, lgb__reg_lambda=0.538824667597043, lgb__subsample=0.7732376566743322; total time=   1.6s
# [CV] END lgb__learning_rate=0.04197529801285681, lgb__max_depth=7, lgb__min_child_samples=122, lgb__n_estimators=696, lgb__num_leaves=73, lgb__reg_alpha=0.2887341884826334, lgb__reg_lambda=0.5035645916507283, lgb__subsample=0.8491745517677156; total time=   1.7s
# [CV] END lgb__learning_rate=0.04197529801285681, lgb__max_depth=7, lgb__min_child_samples=122, lgb__n_estimators=696, lgb__num_leaves=73, lgb__reg_alpha=0.2887341884826334, lgb__reg_lambda=0.5035645916507283, lgb__subsample=0.8491745517677156; total time=   1.6s
# [CV] END lgb__learning_rate=0.04197529801285681, lgb__max_depth=7, lgb__min_child_samples=122, lgb__n_estimators=696, lgb__num_leaves=73, lgb__reg_alpha=0.2887341884826334, lgb__reg_lambda=0.5035645916507283, lgb__subsample=0.8491745517677156; total time=   1.6s
# [CV] END lgb__learning_rate=0.04197529801285681, lgb__max_depth=7, lgb__min_child_samples=122, lgb__n_estimators=696, lgb__num_leaves=73, lgb__reg_alpha=0.2887341884826334, lgb__reg_lambda=0.5035645916507283, lgb__subsample=0.8491745517677156; total time=   1.6s
# [CV] END lgb__learning_rate=0.04197529801285681, lgb__max_depth=7, lgb__min_child_samples=122, lgb__n_estimators=696, lgb__num_leaves=73, lgb__reg_alpha=0.2887341884826334, lgb__reg_lambda=0.5035645916507283, lgb__subsample=0.8491745517677156; total time=   2.1s
# [CV] END lgb__learning_rate=0.06716687886518624, lgb__max_depth=15, lgb__min_child_samples=90, lgb__n_estimators=898, lgb__num_leaves=17, lgb__reg_alpha=0.15080370696865844, lgb__reg_lambda=0.1029575024999787, lgb__subsample=0.7835939392709834; total time=   1.9s
# [CV] END lgb__learning_rate=0.06716687886518624, lgb__max_depth=15, lgb__min_child_samples=90, lgb__n_estimators=898, lgb__num_leaves=17, lgb__reg_alpha=0.15080370696865844, lgb__reg_lambda=0.1029575024999787, lgb__subsample=0.7835939392709834; total time=   1.9s
# [CV] END lgb__learning_rate=0.06716687886518624, lgb__max_depth=15, lgb__min_child_samples=90, lgb__n_estimators=898, lgb__num_leaves=17, lgb__reg_alpha=0.15080370696865844, lgb__reg_lambda=0.1029575024999787, lgb__subsample=0.7835939392709834; total time=   2.0s
# [CV] END lgb__learning_rate=0.06716687886518624, lgb__max_depth=15, lgb__min_child_samples=90, lgb__n_estimators=898, lgb__num_leaves=17, lgb__reg_alpha=0.15080370696865844, lgb__reg_lambda=0.1029575024999787, lgb__subsample=0.7835939392709834; total time=   1.9s
# [CV] END lgb__learning_rate=0.06716687886518624, lgb__max_depth=15, lgb__min_child_samples=90, lgb__n_estimators=898, lgb__num_leaves=17, lgb__reg_alpha=0.15080370696865844, lgb__reg_lambda=0.1029575024999787, lgb__subsample=0.7835939392709834; total time=   1.9s
# [CV] END lgb__learning_rate=0.18257051833366422, lgb__max_depth=17, lgb__min_child_samples=135, lgb__n_estimators=329, lgb__num_leaves=68, lgb__reg_alpha=0.1468358280832689, lgb__reg_lambda=1.9713009082212014, lgb__subsample=0.77261658145345; total time=   1.2s
# [CV] END lgb__learning_rate=0.18257051833366422, lgb__max_depth=17, lgb__min_child_samples=135, lgb__n_estimators=329, lgb__num_leaves=68, lgb__reg_alpha=0.1468358280832689, lgb__reg_lambda=1.9713009082212014, lgb__subsample=0.77261658145345; total time=   1.2s
# [CV] END lgb__learning_rate=0.18257051833366422, lgb__max_depth=17, lgb__min_child_samples=135, lgb__n_estimators=329, lgb__num_leaves=68, lgb__reg_alpha=0.1468358280832689, lgb__reg_lambda=1.9713009082212014, lgb__subsample=0.77261658145345; total time=   1.2s
# [CV] END lgb__learning_rate=0.18257051833366422, lgb__max_depth=17, lgb__min_child_samples=135, lgb__n_estimators=329, lgb__num_leaves=68, lgb__reg_alpha=0.1468358280832689, lgb__reg_lambda=1.9713009082212014, lgb__subsample=0.77261658145345; total time=   1.3s
# [CV] END lgb__learning_rate=0.18257051833366422, lgb__max_depth=17, lgb__min_child_samples=135, lgb__n_estimators=329, lgb__num_leaves=68, lgb__reg_alpha=0.1468358280832689, lgb__reg_lambda=1.9713009082212014, lgb__subsample=0.77261658145345; total time=   1.5s
# [CV] END lgb__learning_rate=0.13770575400711693, lgb__max_depth=9, lgb__min_child_samples=132, lgb__n_estimators=600, lgb__num_leaves=53, lgb__reg_alpha=0.11033493981577597, lgb__reg_lambda=1.264611661187159, lgb__subsample=0.8900589132282684; total time=   2.2s
# [CV] END lgb__learning_rate=0.13770575400711693, lgb__max_depth=9, lgb__min_child_samples=132, lgb__n_estimators=600, lgb__num_leaves=53, lgb__reg_alpha=0.11033493981577597, lgb__reg_lambda=1.264611661187159, lgb__subsample=0.8900589132282684; total time=   1.6s
# [CV] END lgb__learning_rate=0.13770575400711693, lgb__max_depth=9, lgb__min_child_samples=132, lgb__n_estimators=600, lgb__num_leaves=53, lgb__reg_alpha=0.11033493981577597, lgb__reg_lambda=1.264611661187159, lgb__subsample=0.8900589132282684; total time=   1.7s
# [CV] END lgb__learning_rate=0.13770575400711693, lgb__max_depth=9, lgb__min_child_samples=132, lgb__n_estimators=600, lgb__num_leaves=53, lgb__reg_alpha=0.11033493981577597, lgb__reg_lambda=1.264611661187159, lgb__subsample=0.8900589132282684; total time=   1.5s
# [CV] END lgb__learning_rate=0.13770575400711693, lgb__max_depth=9, lgb__min_child_samples=132, lgb__n_estimators=600, lgb__num_leaves=53, lgb__reg_alpha=0.11033493981577597, lgb__reg_lambda=1.264611661187159, lgb__subsample=0.8900589132282684; total time=   2.1s
# [CV] END lgb__learning_rate=0.11179718997420411, lgb__max_depth=14, lgb__min_child_samples=106, lgb__n_estimators=400, lgb__num_leaves=74, lgb__reg_alpha=0.055955553119956265, lgb__reg_lambda=0.08155028310952783, lgb__subsample=0.8772678829564725; total time=   2.2s
# [CV] END lgb__learning_rate=0.11179718997420411, lgb__max_depth=14, lgb__min_child_samples=106, lgb__n_estimators=400, lgb__num_leaves=74, lgb__reg_alpha=0.055955553119956265, lgb__reg_lambda=0.08155028310952783, lgb__subsample=0.8772678829564725; total time=   1.2s
# [CV] END lgb__learning_rate=0.11179718997420411, lgb__max_depth=14, lgb__min_child_samples=106, lgb__n_estimators=400, lgb__num_leaves=74, lgb__reg_alpha=0.055955553119956265, lgb__reg_lambda=0.08155028310952783, lgb__subsample=0.8772678829564725; total time=   1.2s
# [CV] END lgb__learning_rate=0.11179718997420411, lgb__max_depth=14, lgb__min_child_samples=106, lgb__n_estimators=400, lgb__num_leaves=74, lgb__reg_alpha=0.055955553119956265, lgb__reg_lambda=0.08155028310952783, lgb__subsample=0.8772678829564725; total time=   2.3s
# [CV] END lgb__learning_rate=0.11179718997420411, lgb__max_depth=14, lgb__min_child_samples=106, lgb__n_estimators=400, lgb__num_leaves=74, lgb__reg_alpha=0.055955553119956265, lgb__reg_lambda=0.08155028310952783, lgb__subsample=0.8772678829564725; total time=   1.6s
# [CV] END lgb__learning_rate=0.13873722875003366, lgb__max_depth=17, lgb__min_child_samples=99, lgb__n_estimators=710, lgb__num_leaves=34, lgb__reg_alpha=0.10459979618751881, lgb__reg_lambda=0.19235310218284152, lgb__subsample=0.9821569793468812; total time=   2.5s
# [CV] END lgb__learning_rate=0.13873722875003366, lgb__max_depth=17, lgb__min_child_samples=99, lgb__n_estimators=710, lgb__num_leaves=34, lgb__reg_alpha=0.10459979618751881, lgb__reg_lambda=0.19235310218284152, lgb__subsample=0.9821569793468812; total time=   1.9s
# [CV] END lgb__learning_rate=0.13873722875003366, lgb__max_depth=17, lgb__min_child_samples=99, lgb__n_estimators=710, lgb__num_leaves=34, lgb__reg_alpha=0.10459979618751881, lgb__reg_lambda=0.19235310218284152, lgb__subsample=0.9821569793468812; total time=   2.0s
# [CV] END lgb__learning_rate=0.13873722875003366, lgb__max_depth=17, lgb__min_child_samples=99, lgb__n_estimators=710, lgb__num_leaves=34, lgb__reg_alpha=0.10459979618751881, lgb__reg_lambda=0.19235310218284152, lgb__subsample=0.9821569793468812; total time=   2.0s
# [CV] END lgb__learning_rate=0.13873722875003366, lgb__max_depth=17, lgb__min_child_samples=99, lgb__n_estimators=710, lgb__num_leaves=34, lgb__reg_alpha=0.10459979618751881, lgb__reg_lambda=0.19235310218284152, lgb__subsample=0.9821569793468812; total time=   2.1s
# [CV] END lgb__learning_rate=0.08553868400662924, lgb__max_depth=5, lgb__min_child_samples=91, lgb__n_estimators=840, lgb__num_leaves=26, lgb__reg_alpha=0.10231990531507755, lgb__reg_lambda=0.22694704248117814, lgb__subsample=0.9774080854835687; total time=   2.2s
# [CV] END lgb__learning_rate=0.08553868400662924, lgb__max_depth=5, lgb__min_child_samples=91, lgb__n_estimators=840, lgb__num_leaves=26, lgb__reg_alpha=0.10231990531507755, lgb__reg_lambda=0.22694704248117814, lgb__subsample=0.9774080854835687; total time=   1.7s
# [CV] END lgb__learning_rate=0.08553868400662924, lgb__max_depth=5, lgb__min_child_samples=91, lgb__n_estimators=840, lgb__num_leaves=26, lgb__reg_alpha=0.10231990531507755, lgb__reg_lambda=0.22694704248117814, lgb__subsample=0.9774080854835687; total time=   1.6s
# [CV] END lgb__learning_rate=0.08553868400662924, lgb__max_depth=5, lgb__min_child_samples=91, lgb__n_estimators=840, lgb__num_leaves=26, lgb__reg_alpha=0.10231990531507755, lgb__reg_lambda=0.22694704248117814, lgb__subsample=0.9774080854835687; total time=   1.7s
# [CV] END lgb__learning_rate=0.08553868400662924, lgb__max_depth=5, lgb__min_child_samples=91, lgb__n_estimators=840, lgb__num_leaves=26, lgb__reg_alpha=0.10231990531507755, lgb__reg_lambda=0.22694704248117814, lgb__subsample=0.9774080854835687; total time=   1.6s
# [CV] END lgb__learning_rate=0.1766944771423864, lgb__max_depth=1, lgb__min_child_samples=16, lgb__n_estimators=343, lgb__num_leaves=105, lgb__reg_alpha=0.29465050299883067, lgb__reg_lambda=1.0332717825420286, lgb__subsample=0.7782487524491226; total time=   0.5s
# [CV] END lgb__learning_rate=0.1766944771423864, lgb__max_depth=1, lgb__min_child_samples=16, lgb__n_estimators=343, lgb__num_leaves=105, lgb__reg_alpha=0.29465050299883067, lgb__reg_lambda=1.0332717825420286, lgb__subsample=0.7782487524491226; total time=   0.5s
# [CV] END lgb__learning_rate=0.1766944771423864, lgb__max_depth=1, lgb__min_child_samples=16, lgb__n_estimators=343, lgb__num_leaves=105, lgb__reg_alpha=0.29465050299883067, lgb__reg_lambda=1.0332717825420286, lgb__subsample=0.7782487524491226; total time=   0.5s
# [CV] END lgb__learning_rate=0.1766944771423864, lgb__max_depth=1, lgb__min_child_samples=16, lgb__n_estimators=343, lgb__num_leaves=105, lgb__reg_alpha=0.29465050299883067, lgb__reg_lambda=1.0332717825420286, lgb__subsample=0.7782487524491226; total time=   0.7s
# [CV] END lgb__learning_rate=0.1766944771423864, lgb__max_depth=1, lgb__min_child_samples=16, lgb__n_estimators=343, lgb__num_leaves=105, lgb__reg_alpha=0.29465050299883067, lgb__reg_lambda=1.0332717825420286, lgb__subsample=0.7782487524491226; total time=   0.5s
# [CV] END lgb__learning_rate=0.19928820295400562, lgb__max_depth=10, lgb__min_child_samples=46, lgb__n_estimators=359, lgb__num_leaves=24, lgb__reg_alpha=0.08366140577765456, lgb__reg_lambda=1.4007156599455426, lgb__subsample=0.9539983426714918; total time=   1.1s
# [CV] END lgb__learning_rate=0.19928820295400562, lgb__max_depth=10, lgb__min_child_samples=46, lgb__n_estimators=359, lgb__num_leaves=24, lgb__reg_alpha=0.08366140577765456, lgb__reg_lambda=1.4007156599455426, lgb__subsample=0.9539983426714918; total time=   0.9s
# [CV] END lgb__learning_rate=0.19928820295400562, lgb__max_depth=10, lgb__min_child_samples=46, lgb__n_estimators=359, lgb__num_leaves=24, lgb__reg_alpha=0.08366140577765456, lgb__reg_lambda=1.4007156599455426, lgb__subsample=0.9539983426714918; total time=   1.0s
# [CV] END lgb__learning_rate=0.19928820295400562, lgb__max_depth=10, lgb__min_child_samples=46, lgb__n_estimators=359, lgb__num_leaves=24, lgb__reg_alpha=0.08366140577765456, lgb__reg_lambda=1.4007156599455426, lgb__subsample=0.9539983426714918; total time=   0.8s
# [CV] END lgb__learning_rate=0.19928820295400562, lgb__max_depth=10, lgb__min_child_samples=46, lgb__n_estimators=359, lgb__num_leaves=24, lgb__reg_alpha=0.08366140577765456, lgb__reg_lambda=1.4007156599455426, lgb__subsample=0.9539983426714918; total time=   0.9s
# [CV] END lgb__learning_rate=0.17270161545683757, lgb__max_depth=20, lgb__min_child_samples=129, lgb__n_estimators=872, lgb__num_leaves=39, lgb__reg_alpha=0.2552785346302538, lgb__reg_lambda=1.871269988441895, lgb__subsample=0.935602195334183; total time=   2.9s
# [CV] END lgb__learning_rate=0.17270161545683757, lgb__max_depth=20, lgb__min_child_samples=129, lgb__n_estimators=872, lgb__num_leaves=39, lgb__reg_alpha=0.2552785346302538, lgb__reg_lambda=1.871269988441895, lgb__subsample=0.935602195334183; total time=   3.1s
# [CV] END lgb__learning_rate=0.17270161545683757, lgb__max_depth=20, lgb__min_child_samples=129, lgb__n_estimators=872, lgb__num_leaves=39, lgb__reg_alpha=0.2552785346302538, lgb__reg_lambda=1.871269988441895, lgb__subsample=0.935602195334183; total time=   3.2s
# [CV] END lgb__learning_rate=0.17270161545683757, lgb__max_depth=20, lgb__min_child_samples=129, lgb__n_estimators=872, lgb__num_leaves=39, lgb__reg_alpha=0.2552785346302538, lgb__reg_lambda=1.871269988441895, lgb__subsample=0.935602195334183; total time=   3.2s
# [CV] END lgb__learning_rate=0.17270161545683757, lgb__max_depth=20, lgb__min_child_samples=129, lgb__n_estimators=872, lgb__num_leaves=39, lgb__reg_alpha=0.2552785346302538, lgb__reg_lambda=1.871269988441895, lgb__subsample=0.935602195334183; total time=   3.2s
# [CV] END lgb__learning_rate=0.13710776839570346, lgb__max_depth=1, lgb__min_child_samples=121, lgb__n_estimators=709, lgb__num_leaves=104, lgb__reg_alpha=0.19905053073241674, lgb__reg_lambda=0.010123167692437374, lgb__subsample=0.7482424154252496; total time=   0.9s
# [CV] END lgb__learning_rate=0.13710776839570346, lgb__max_depth=1, lgb__min_child_samples=121, lgb__n_estimators=709, lgb__num_leaves=104, lgb__reg_alpha=0.19905053073241674, lgb__reg_lambda=0.010123167692437374, lgb__subsample=0.7482424154252496; total time=   0.9s
# [CV] END lgb__learning_rate=0.13710776839570346, lgb__max_depth=1, lgb__min_child_samples=121, lgb__n_estimators=709, lgb__num_leaves=104, lgb__reg_alpha=0.19905053073241674, lgb__reg_lambda=0.010123167692437374, lgb__subsample=0.7482424154252496; total time=   0.9s
# [CV] END lgb__learning_rate=0.13710776839570346, lgb__max_depth=1, lgb__min_child_samples=121, lgb__n_estimators=709, lgb__num_leaves=104, lgb__reg_alpha=0.19905053073241674, lgb__reg_lambda=0.010123167692437374, lgb__subsample=0.7482424154252496; total time=   1.0s
# [CV] END lgb__learning_rate=0.13710776839570346, lgb__max_depth=1, lgb__min_child_samples=121, lgb__n_estimators=709, lgb__num_leaves=104, lgb__reg_alpha=0.19905053073241674, lgb__reg_lambda=0.010123167692437374, lgb__subsample=0.7482424154252496; total time=   0.9s
# [CV] END lgb__learning_rate=0.11425941997965136, lgb__max_depth=20, lgb__min_child_samples=77, lgb__n_estimators=597, lgb__num_leaves=36, lgb__reg_alpha=0.05364681276639864, lgb__reg_lambda=0.7329375691657198, lgb__subsample=0.9232511569169686; total time=   1.7s
# [CV] END lgb__learning_rate=0.11425941997965136, lgb__max_depth=20, lgb__min_child_samples=77, lgb__n_estimators=597, lgb__num_leaves=36, lgb__reg_alpha=0.05364681276639864, lgb__reg_lambda=0.7329375691657198, lgb__subsample=0.9232511569169686; total time=   1.6s
# [CV] END lgb__learning_rate=0.11425941997965136, lgb__max_depth=20, lgb__min_child_samples=77, lgb__n_estimators=597, lgb__num_leaves=36, lgb__reg_alpha=0.05364681276639864, lgb__reg_lambda=0.7329375691657198, lgb__subsample=0.9232511569169686; total time=   1.8s
# [CV] END lgb__learning_rate=0.11425941997965136, lgb__max_depth=20, lgb__min_child_samples=77, lgb__n_estimators=597, lgb__num_leaves=36, lgb__reg_alpha=0.05364681276639864, lgb__reg_lambda=0.7329375691657198, lgb__subsample=0.9232511569169686; total time=   1.7s
# [CV] END lgb__learning_rate=0.11425941997965136, lgb__max_depth=20, lgb__min_child_samples=77, lgb__n_estimators=597, lgb__num_leaves=36, lgb__reg_alpha=0.05364681276639864, lgb__reg_lambda=0.7329375691657198, lgb__subsample=0.9232511569169686; total time=   1.8s
# [CV] END lgb__learning_rate=0.14697858560790458, lgb__max_depth=-1, lgb__min_child_samples=124, lgb__n_estimators=669, lgb__num_leaves=37, lgb__reg_alpha=0.07319689301372508, lgb__reg_lambda=1.9460211095048912, lgb__subsample=0.817929317400028; total time=   2.1s
# [CV] END lgb__learning_rate=0.14697858560790458, lgb__max_depth=-1, lgb__min_child_samples=124, lgb__n_estimators=669, lgb__num_leaves=37, lgb__reg_alpha=0.07319689301372508, lgb__reg_lambda=1.9460211095048912, lgb__subsample=0.817929317400028; total time=   2.1s
# [CV] END lgb__learning_rate=0.14697858560790458, lgb__max_depth=-1, lgb__min_child_samples=124, lgb__n_estimators=669, lgb__num_leaves=37, lgb__reg_alpha=0.07319689301372508, lgb__reg_lambda=1.9460211095048912, lgb__subsample=0.817929317400028; total time=   2.2s
# [CV] END lgb__learning_rate=0.14697858560790458, lgb__max_depth=-1, lgb__min_child_samples=124, lgb__n_estimators=669, lgb__num_leaves=37, lgb__reg_alpha=0.07319689301372508, lgb__reg_lambda=1.9460211095048912, lgb__subsample=0.817929317400028; total time=   1.9s
# [CV] END lgb__learning_rate=0.14697858560790458, lgb__max_depth=-1, lgb__min_child_samples=124, lgb__n_estimators=669, lgb__num_leaves=37, lgb__reg_alpha=0.07319689301372508, lgb__reg_lambda=1.9460211095048912, lgb__subsample=0.817929317400028; total time=   2.0s
# [CV] END lgb__learning_rate=0.17948884548365154, lgb__max_depth=0, lgb__min_child_samples=30, lgb__n_estimators=808, lgb__num_leaves=43, lgb__reg_alpha=0.2006772178989299, lgb__reg_lambda=1.7283351301438061, lgb__subsample=0.7690555804724666; total time=   3.1s
# [CV] END lgb__learning_rate=0.17948884548365154, lgb__max_depth=0, lgb__min_child_samples=30, lgb__n_estimators=808, lgb__num_leaves=43, lgb__reg_alpha=0.2006772178989299, lgb__reg_lambda=1.7283351301438061, lgb__subsample=0.7690555804724666; total time=   2.2s
# [CV] END lgb__learning_rate=0.17948884548365154, lgb__max_depth=0, lgb__min_child_samples=30, lgb__n_estimators=808, lgb__num_leaves=43, lgb__reg_alpha=0.2006772178989299, lgb__reg_lambda=1.7283351301438061, lgb__subsample=0.7690555804724666; total time=   2.3s
# [CV] END lgb__learning_rate=0.17948884548365154, lgb__max_depth=0, lgb__min_child_samples=30, lgb__n_estimators=808, lgb__num_leaves=43, lgb__reg_alpha=0.2006772178989299, lgb__reg_lambda=1.7283351301438061, lgb__subsample=0.7690555804724666; total time=   2.3s
# [CV] END lgb__learning_rate=0.17948884548365154, lgb__max_depth=0, lgb__min_child_samples=30, lgb__n_estimators=808, lgb__num_leaves=43, lgb__reg_alpha=0.2006772178989299, lgb__reg_lambda=1.7283351301438061, lgb__subsample=0.7690555804724666; total time=   2.2s
# [CV] END lgb__learning_rate=0.10484674217810294, lgb__max_depth=2, lgb__min_child_samples=44, lgb__n_estimators=391, lgb__num_leaves=64, lgb__reg_alpha=0.013081131526330125, lgb__reg_lambda=1.989101021594682, lgb__subsample=0.8409833541972829; total time=   0.6s
# [CV] END lgb__learning_rate=0.10484674217810294, lgb__max_depth=2, lgb__min_child_samples=44, lgb__n_estimators=391, lgb__num_leaves=64, lgb__reg_alpha=0.013081131526330125, lgb__reg_lambda=1.989101021594682, lgb__subsample=0.8409833541972829; total time=   0.6s
# [CV] END lgb__learning_rate=0.10484674217810294, lgb__max_depth=2, lgb__min_child_samples=44, lgb__n_estimators=391, lgb__num_leaves=64, lgb__reg_alpha=0.013081131526330125, lgb__reg_lambda=1.989101021594682, lgb__subsample=0.8409833541972829; total time=   0.6s
# [CV] END lgb__learning_rate=0.10484674217810294, lgb__max_depth=2, lgb__min_child_samples=44, lgb__n_estimators=391, lgb__num_leaves=64, lgb__reg_alpha=0.013081131526330125, lgb__reg_lambda=1.989101021594682, lgb__subsample=0.8409833541972829; total time=   0.6s
# [CV] END lgb__learning_rate=0.10484674217810294, lgb__max_depth=2, lgb__min_child_samples=44, lgb__n_estimators=391, lgb__num_leaves=64, lgb__reg_alpha=0.013081131526330125, lgb__reg_lambda=1.989101021594682, lgb__subsample=0.8409833541972829; total time=   0.6s
# [CV] END lgb__learning_rate=0.06311646494138413, lgb__max_depth=4, lgb__min_child_samples=108, lgb__n_estimators=236, lgb__num_leaves=39, lgb__reg_alpha=0.09922509140115411, lgb__reg_lambda=1.1055299336709798, lgb__subsample=0.8716877407512514; total time=   0.5s
# [CV] END lgb__learning_rate=0.06311646494138413, lgb__max_depth=4, lgb__min_child_samples=108, lgb__n_estimators=236, lgb__num_leaves=39, lgb__reg_alpha=0.09922509140115411, lgb__reg_lambda=1.1055299336709798, lgb__subsample=0.8716877407512514; total time=   0.5s
# [CV] END lgb__learning_rate=0.06311646494138413, lgb__max_depth=4, lgb__min_child_samples=108, lgb__n_estimators=236, lgb__num_leaves=39, lgb__reg_alpha=0.09922509140115411, lgb__reg_lambda=1.1055299336709798, lgb__subsample=0.8716877407512514; total time=   0.5s
# [CV] END lgb__learning_rate=0.06311646494138413, lgb__max_depth=4, lgb__min_child_samples=108, lgb__n_estimators=236, lgb__num_leaves=39, lgb__reg_alpha=0.09922509140115411, lgb__reg_lambda=1.1055299336709798, lgb__subsample=0.8716877407512514; total time=   0.5s
# [CV] END lgb__learning_rate=0.06311646494138413, lgb__max_depth=4, lgb__min_child_samples=108, lgb__n_estimators=236, lgb__num_leaves=39, lgb__reg_alpha=0.09922509140115411, lgb__reg_lambda=1.1055299336709798, lgb__subsample=0.8716877407512514; total time=   0.5s
# [CV] END lgb__learning_rate=0.1962630009060487, lgb__max_depth=18, lgb__min_child_samples=76, lgb__n_estimators=327, lgb__num_leaves=33, lgb__reg_alpha=0.16704037873750505, lgb__reg_lambda=1.872309548321562, lgb__subsample=0.9088089390024918; total time=   0.9s
# [CV] END lgb__learning_rate=0.1962630009060487, lgb__max_depth=18, lgb__min_child_samples=76, lgb__n_estimators=327, lgb__num_leaves=33, lgb__reg_alpha=0.16704037873750505, lgb__reg_lambda=1.872309548321562, lgb__subsample=0.9088089390024918; total time=   0.9s
# [CV] END lgb__learning_rate=0.1962630009060487, lgb__max_depth=18, lgb__min_child_samples=76, lgb__n_estimators=327, lgb__num_leaves=33, lgb__reg_alpha=0.16704037873750505, lgb__reg_lambda=1.872309548321562, lgb__subsample=0.9088089390024918; total time=   0.9s
# [CV] END lgb__learning_rate=0.1962630009060487, lgb__max_depth=18, lgb__min_child_samples=76, lgb__n_estimators=327, lgb__num_leaves=33, lgb__reg_alpha=0.16704037873750505, lgb__reg_lambda=1.872309548321562, lgb__subsample=0.9088089390024918; total time=   0.9s
# [CV] END lgb__learning_rate=0.1962630009060487, lgb__max_depth=18, lgb__min_child_samples=76, lgb__n_estimators=327, lgb__num_leaves=33, lgb__reg_alpha=0.16704037873750505, lgb__reg_lambda=1.872309548321562, lgb__subsample=0.9088089390024918; total time=   0.9s
# [CV] END lgb__learning_rate=0.11831162231697934, lgb__max_depth=16, lgb__min_child_samples=41, lgb__n_estimators=862, lgb__num_leaves=81, lgb__reg_alpha=0.07624909472092163, lgb__reg_lambda=0.5905811768378775, lgb__subsample=0.7967652292715801; total time=   3.1s
# [CV] END lgb__learning_rate=0.11831162231697934, lgb__max_depth=16, lgb__min_child_samples=41, lgb__n_estimators=862, lgb__num_leaves=81, lgb__reg_alpha=0.07624909472092163, lgb__reg_lambda=0.5905811768378775, lgb__subsample=0.7967652292715801; total time=   2.9s
# [CV] END lgb__learning_rate=0.11831162231697934, lgb__max_depth=16, lgb__min_child_samples=41, lgb__n_estimators=862, lgb__num_leaves=81, lgb__reg_alpha=0.07624909472092163, lgb__reg_lambda=0.5905811768378775, lgb__subsample=0.7967652292715801; total time=   3.7s
# [CV] END lgb__learning_rate=0.11831162231697934, lgb__max_depth=16, lgb__min_child_samples=41, lgb__n_estimators=862, lgb__num_leaves=81, lgb__reg_alpha=0.07624909472092163, lgb__reg_lambda=0.5905811768378775, lgb__subsample=0.7967652292715801; total time=   2.8s
# [CV] END lgb__learning_rate=0.11831162231697934, lgb__max_depth=16, lgb__min_child_samples=41, lgb__n_estimators=862, lgb__num_leaves=81, lgb__reg_alpha=0.07624909472092163, lgb__reg_lambda=0.5905811768378775, lgb__subsample=0.7967652292715801; total time=   2.9s
# [CV] END lgb__learning_rate=0.17124726103568816, lgb__max_depth=7, lgb__min_child_samples=52, lgb__n_estimators=445, lgb__num_leaves=63, lgb__reg_alpha=0.16584599307237233, lgb__reg_lambda=0.593020287295597, lgb__subsample=0.8259342569338829; total time=   0.9s
# [CV] END lgb__learning_rate=0.17124726103568816, lgb__max_depth=7, lgb__min_child_samples=52, lgb__n_estimators=445, lgb__num_leaves=63, lgb__reg_alpha=0.16584599307237233, lgb__reg_lambda=0.593020287295597, lgb__subsample=0.8259342569338829; total time=   0.9s
# [CV] END lgb__learning_rate=0.17124726103568816, lgb__max_depth=7, lgb__min_child_samples=52, lgb__n_estimators=445, lgb__num_leaves=63, lgb__reg_alpha=0.16584599307237233, lgb__reg_lambda=0.593020287295597, lgb__subsample=0.8259342569338829; total time=   0.9s
# [CV] END lgb__learning_rate=0.17124726103568816, lgb__max_depth=7, lgb__min_child_samples=52, lgb__n_estimators=445, lgb__num_leaves=63, lgb__reg_alpha=0.16584599307237233, lgb__reg_lambda=0.593020287295597, lgb__subsample=0.8259342569338829; total time=   0.9s
# [CV] END lgb__learning_rate=0.17124726103568816, lgb__max_depth=7, lgb__min_child_samples=52, lgb__n_estimators=445, lgb__num_leaves=63, lgb__reg_alpha=0.16584599307237233, lgb__reg_lambda=0.593020287295597, lgb__subsample=0.8259342569338829; total time=   0.9s
# [CV] END lgb__learning_rate=0.058679319282947034, lgb__max_depth=11, lgb__min_child_samples=69, lgb__n_estimators=705, lgb__num_leaves=22, lgb__reg_alpha=0.15045488840615986, lgb__reg_lambda=1.5965903579335503, lgb__subsample=0.8949891792333295; total time=   1.8s
# [CV] END lgb__learning_rate=0.058679319282947034, lgb__max_depth=11, lgb__min_child_samples=69, lgb__n_estimators=705, lgb__num_leaves=22, lgb__reg_alpha=0.15045488840615986, lgb__reg_lambda=1.5965903579335503, lgb__subsample=0.8949891792333295; total time=   1.7s
# [CV] END lgb__learning_rate=0.058679319282947034, lgb__max_depth=11, lgb__min_child_samples=69, lgb__n_estimators=705, lgb__num_leaves=22, lgb__reg_alpha=0.15045488840615986, lgb__reg_lambda=1.5965903579335503, lgb__subsample=0.8949891792333295; total time=   1.7s
# [CV] END lgb__learning_rate=0.058679319282947034, lgb__max_depth=11, lgb__min_child_samples=69, lgb__n_estimators=705, lgb__num_leaves=22, lgb__reg_alpha=0.15045488840615986, lgb__reg_lambda=1.5965903579335503, lgb__subsample=0.8949891792333295; total time=   1.8s
# [CV] END lgb__learning_rate=0.058679319282947034, lgb__max_depth=11, lgb__min_child_samples=69, lgb__n_estimators=705, lgb__num_leaves=22, lgb__reg_alpha=0.15045488840615986, lgb__reg_lambda=1.5965903579335503, lgb__subsample=0.8949891792333295; total time=   1.7s
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('lgb',
#                                               LGBMClassifier(class_weight='balanced',
#                                                              n_jobs=-1,
#                                                              random_state=42,
#                                                              verbose=-1))]),
#                    n_iter=40, n_jobs=1,
#                    param_distributions={'lgb__learning_rate': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x0000019EEF09B230>,
#                                         'lgb__max_dept...
#                                         'lgb__num_leaves': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000019EEFD0F610>,
#                                         'lgb__reg_alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x0000019EEFD0F250>,
#                                         'lgb__reg_lambda': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x0000019EEF0B2C40>,
#                                         'lgb__subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x0000019EEFD0E990>},
#                    random_state=42, scoring='recall', verbose=2)

# %%
print("Mejores params:", lgb_random.best_params_)
print("Mejor recall (CV):", lgb_random.best_score_)
# Out:
# Mejores params: {'lgb__learning_rate': np.float64(0.06311646494138413), 'lgb__max_depth': 4, 'lgb__min_child_samples': 108, 'lgb__n_estimators': 236, 'lgb__num_leaves': 39, 'lgb__reg_alpha': np.float64(0.09922509140115411), 'lgb__reg_lambda': np.float64(1.1055299336709798), 'lgb__subsample': np.float64(0.8716877407512514)}
# Mejor recall (CV): 0.7068589933914624

# %%
best_model = lgb_random.best_estimator_
y_proba = best_model.predict_proba(X_test)[:, 1]

for t in [0.45, 0.5, 0.55, 0.6]:
    y_t = (y_proba >= t).astype(int)
    print(
        f"t={t:0.2f}",
        "recall:", round(recall_score(y_test, y_t), 3),
        "precision:", round(precision_score(y_test, y_t), 3)
    )

t_final = 0.5
y_pred_final = (y_proba >= t_final).astype(int)
print(classification_report(y_test, y_pred_final))
# Out:
# t=0.45 recall: 0.814 precision: 0.744
# t=0.50 recall: 0.706 precision: 0.754
# t=0.55 recall: 0.502 precision: 0.776
# t=0.60 recall: 0.339 precision: 0.793
#               precision    recall  f1-score   support
#
#            0       0.43      0.49      0.45     19502
#            1       0.75      0.71      0.73     43545
#
#     accuracy                           0.64     63047
#    macro avg       0.59      0.60      0.59     63047
# weighted avg       0.65      0.64      0.64     63047

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_final)

plt.show()

# %%
# 9493 → Verdaderos Negativos (TN)
# Clientes buenos que el modelo deja con prima normal.

# 10000 → Falsos Positivos (FP)
# Clientes buenos a los que subirías la prima injustamente.

# 12802 → Falsos Negativos (FN)
# Clientes de riesgo que el modelo no detecta.

# 30743 → Verdaderos Positivos (TP)
# Clientes de riesgo detectados correctamente.

# %% [markdown]
# Guardamos el modelo

# %%
import pickle

with open('src/models/best_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)
